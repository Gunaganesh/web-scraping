# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
URL = "https://www.indeed.com/jobs?q=data+scientist+$20,000&l=New+York&start=10"
page = requests.get(URL)
soup = BeautifulSoup(page.text, "html.parser")
div = soup.find_all("div", attrs={"class":"row"})
content = str(div)
print(content)
# Out:
# [<div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="b0fea7a51c0d01ce" data-tn-component="organicJob" id="p_b0fea7a51c0d01ce">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=b0fea7a51c0d01ce&amp;fccid=b4048be2884af072&amp;vjs=3" id="jl_b0fea7a51c0d01ce" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Data Scientist">
# <b>Data</b> <b>Scientist</b></a>
# </h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Bny-Mellon" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b0fea7a51c0d01ce&amp;jcid=b4048be2884af072')" rel="noopener" target="_blank">
# BNY Mellon</a></span>
# <span class="ratingsDisplay">
# ...

# %%
jobtitle = soup.find_all("a", attrs={"class":"jobtitle"})
content1 = str(jobtitle)
print(content1)

#for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
# Out:
# [<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=568acbc8cec72a11&amp;fccid=6f49e88f14c18b75&amp;vjs=3" id="jl_568acbc8cec72a11" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Junior Data Scientist">
# Junior <b>Data</b> <b>Scientist</b></a>, <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=744b5d8f70078ee6&amp;fccid=b5ff6a9d6acf7028&amp;vjs=3" id="jl_744b5d8f70078ee6" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="noopener nofollow" target="_blank" title="Data Scientist">
# ...

# %%
def extract_job(soup): 
    jobs = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
            jobs.append(a["title"])
    return(jobs)
extract_job(soup)
# Out:
# ['Junior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'DATA SCIENTIST',
#  'Associate Data Scientist- Ad Studio',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - Shops Seller Ecosystem',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Associate, Data Scientist (Virtual / Remote - New York, NY)',
#  'Data Scientist',
#  'Data Science Intern']

# %%
company = soup.find_all(name="span", attrs={"class":"company"})
company_name=str(company)
company_name
# Out:
# '[<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Mars" onmousedown="this.href = appendParamsOnce(this.href, \'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=568acbc8cec72a11&amp;jcid=6f49e88f14c18b75\')" rel="noopener" target="_blank">\nMars</a></span>, <span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Naval-Nuclear-Laboratory" onmousedown="this.href = appendParamsOnce(this.href, \'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=744b5d8f70078ee6&amp;jcid=13aa4bf1cb237726\')" rel="noopener" target="_blank">\nNaval Nuclear Laboratory</a></span>, <span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Northwestern-Mutual" onmousedown="this.href = appendParamsOnce(this.href, \'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=bcb7efc29a566c79&amp;jcid=f2cbb7715eae48aa\')" rel="noopener" target="_blank">\nNorthwestern Mutual</a></span>, <span class
# ...

# %%
def extract_com(soup): 
    company = []
    spans = soup.findAll("span", attrs={"class": "company"})
    for span in spans:
        company.append(span.text.strip())
    return(company)
extract_com(soup)
# Out:
# ['BNY Mellon',
#  'Naval Nuclear Laboratory',
#  'QuaEra',
#  'IBM',
#  'Northwestern Mutual',
#  'Spotify',
#  'eBay Inc.',
#  'pulseData',
#  'Sightly Enterprises',
#  'Unite Us']

# %%
location = soup.find_all(name="span", attrs={"class":"location"})
location_name=str(location)
location
# Out:
# [<span class="location accessible-contrast-color-location">New York, NY</span>,
#  <span class="location accessible-contrast-color-location">Niskayuna, NY 12309</span>,
#  <span class="location accessible-contrast-color-location">New York, NY</span>,
#  <span class="location accessible-contrast-color-location">New York, NY 10286 <span style="font-size: smaller">(Tribeca area)</span></span>,
#  <span class="location accessible-contrast-color-location">New York, NY</span>,
#  <span class="location accessible-contrast-color-location">New York, NY</span>,
#  <span class="location accessible-contrast-color-location">New York, NY</span>,
#  <span class="location accessible-contrast-color-location">Manhattan, NY</span>,
#  <span class="location accessible-contrast-color-location">New York, NY 10003 <span style="font-size: smaller">(Flatiron District area)</span></span>,
#  <span class="location accessible-contrast-color-location">New York, NY</span>,
# ...

# %%
def extract_location(soup): 
    locations = []
    spans = soup.findAll('span', attrs={'class': 'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)
extract_location(soup)
# Out:
# ['New York, NY',
#  'Niskayuna, NY 12309',
#  'New York, NY',
#  'New York, NY 10286 (Tribeca area)',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'Manhattan, NY',
#  'New York, NY 10003 (Flatiron District area)',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'New York State',
#  'New York, NY 10018 (Garment District area)',
#  'New York, NY']

# %%
Com_Name = soup.find_all(name="a", attrs={"data-tn-element":"companyName"})
Com_Name
# Out:
# [<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Mars" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=568acbc8cec72a11&amp;jcid=6f49e88f14c18b75')" rel="noopener" target="_blank">
#  Mars</a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/IBM" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c7fe6ff227cd1846&amp;jcid=de71a49b535e21cb')" rel="noopener" target="_blank">
#  IBM</a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Bny-Mellon" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b0fea7a51c0d01ce&amp;jcid=b4048be2884af072')" rel="noopener" target="_blank">
#  BNY Mellon</a>,
# ...

# %%
project_ref = soup.findAll('>h1', {'class': 'turnstileLink'})
project_href = [project.findChildren('a')[0].href for project in project_ref if project.findChildren('a')]
print(project_href)
# Out:
# []
